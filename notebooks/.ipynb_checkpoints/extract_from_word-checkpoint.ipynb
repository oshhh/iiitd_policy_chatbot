# %%
from helper import *

# %% [markdown]
# # Read PDF

# %%
def create_doc_tree(filename):
    pdf_file = filename + '.pdf'
    docx_file = filename + '.docx'
    # if docx doesn't exist
    # parse(pdf_file, docx_file)

    document = Document(docx_file)
    id_ = 0
    text = {}
    adj_list = {}
    parent = {}
    prev_titles = []
    for para in document.paragraphs:
        if para.text:
            id_ += 1
            # get size
            size = 0
            if para.style.font.size != None:
                size = para.style.font.size/12700
            for run in para.runs:
                if run.font.size:
                    size = max(size, run.font.size/12700)
            # get prev title list
            while len(prev_titles) and prev_titles[-1]['size'] <= size:
                prev_titles.pop()
            if prev_titles:
                adj_list[prev_titles[-1]['id']].append(id_)
                parent[id_] = prev_titles[-1]['id']
            else:
                parent[id_] = None
            prev_titles.append({'size': size, 'id': id_})
            adj_list[id_] = []
            text[id_] = preprocess_paragraph(para.text)
    return text, adj_list, parent

def create_kg(documents):
    subject_edges = set([])
    modifier_edges = set([])
    subject_modifier_edges = set([])
    relation_edges = []
    other_edges = set([])

    did = 0
    tid = 10000
    pid = 20000
    sid = 30000
    eid = 40000
    xid = 50000
    count = 0
    eid_to_text = {}
    text_to_eid = {}
    sid_to_text = {}
    text_to_sid = {}
    pid_to_text = {}
    text_to_pid = {}
    tid_to_text = {}
    text_to_tid = {}
    did_to_text = {}
    text_to_did = {}
    xid_to_text = {}
    text_to_xid = {}
    # for each document get the paragraphs and topics
    for doc in documents:
        if doc not in text_to_did:
            text_to_did[doc] = did
            did_to_text[did] = doc
            did += 1
        # read document in python
        text, adj_list, parent = create_doc_tree(doc)
        
        # traverse doc tree to identify paragraphs and topics in the document
        for node in adj_list:
            if adj_list[node]:
                if text[node] not in text_to_tid:
                    text_to_tid[text[node]] = tid
                    tid_to_text[tid] = text[node]
                    tid += 1
                if parent[node]:
                    if text[parent[node]] not in text_to_tid:
                        text_to_tid[text[parent[node]]] = tid
                        tid_to_text[tid] = text[parent[node]]
                        tid += 1
                    other_edges.add((text_to_tid[text[node]], 'about_concept', text_to_tid[text[parent[node]]]))
            else:
                if text[node] not in text_to_pid:
                    text_to_pid[text[node]] = pid
                    pid_to_text[pid] = text[node]
                    pid += 1
                if text[parent[node]] not in text_to_tid:
                    text_to_tid[text[parent[node]]] = tid
                    tid_to_text[tid] = text[parent[node]]
                    tid += 1
                other_edges.add((text_to_pid[text[node]], 'about_concept', text_to_tid[text[parent[node]]]))
                other_edges.add((text_to_pid[text[node]], 'from_document', text_to_did[doc]))
    
    # convert topics to lower case
    for tid in tid_to_text:
        tid_to_text[tid] = {
            'text': tid_to_text[tid].lower(),
            'keywords': [k[0] for k in find_keywords(tid_to_text[tid].lower())]
        }
    
    # for each paragraph get sentences
    for pid in pid_to_text:
        sentences = split_into_sentences(pid_to_text[pid])
        for sentence in sentences:
            if sentence not in text_to_sid:
                text_to_sid[sentence] = sid
                sid_to_text[sid] = sentence
                sid += 1
            other_edges.add((pid, 'contains_sentence', text_to_sid[sentence]))
    
    # for each sentence get extractions
    for sid in sid_to_text:
        extractions = extract(sid_to_text[sid])
        if extractions:
            count += 1
            for extraction in extractions:
                eid_to_text[eid] = extraction
                other_edges.add((sid, 'contains_extraction', eid))
                eid += 1
        else:
            keywords = find_keywords(sid_to_text[sid])
            for keyword in keywords:
                if keyword[0] not in text_to_xid:
                    text_to_xid[keyword[0]] = xid
                    xid_to_text[xid] = keyword
                    xid += 1
                other_edges.add((sid, 'about_entity', text_to_xid[keyword[0]]))
    
    # canonicalise the obtained extractions
    canonicalise(eid_to_text)
    
    # for each extraction create entities and relations
    for eid in eid_to_text:
        ext = eid_to_text[eid]
        
        if ext['subject'][0] not in text_to_xid:
            text_to_xid[ext['subject'][0]] = xid
            xid_to_text[xid] = ext['subject']
            xid += 1
        
        subject_edges.add((eid, 'subject', text_to_xid[ext['subject'][0]]))

        if ext['object'][0] not in text_to_xid:
            text_to_xid[ext['object'][0]] = xid
            xid_to_text[xid] = ext['object']
            xid += 1

        relation_edges.append((eid, ext['relation'], text_to_xid[ext['object'][0]], list(ext['rel_synsets'])))
        
        for modifier in ext['modifiers']:
            if modifier['m_obj'][0] not in text_to_xid:
                text_to_xid[modifier['m_obj'][0]] = xid
                xid_to_text[xid] = modifier['m_obj']
                xid += 1

            modifier_edges.add((eid, modifier['m_rel'], text_to_xid[modifier['m_obj'][0]]))
            
        for subject_modifier in ext['subject_modifiers']:
            if subject_modifier['m_obj'][0] not in text_to_xid:
                text_to_xid[subject_modifier['m_obj'][0]] = xid
                xid_to_text[xid] = subject_modifier['m_obj']
                xid += 1

            subject_modifier_edges.add((eid, subject_modifier['m_rel'], text_to_xid[subject_modifier['m_obj'][0]]))
    
    print(did, tid, pid, sid, eid, xid, count, round(10000 * count/sid)/100)
    
    offset = {
        'documents': 0,
        'topics': len(did_to_text),
        'paragraphs': len(did_to_text) + len(tid_to_text),
        'sentences': len(did_to_text) + len(tid_to_text) + len(pid_to_text),
        'extractions': len(did_to_text) + len(tid_to_text) + len(pid_to_text) + len(sid_to_text),
        'entities':  len(did_to_text) + len(tid_to_text) + len(pid_to_text) + len(sid_to_text) + len(eid_to_text)
    }
    
    vertices = {
        'documents': list({'id': k, 'text': did_to_text[k]} for k in did_to_text.keys()),
        'topics': list({'id': k, 'text': tid_to_text[k]['text'], 'keywords': tid_to_text[k]['keywords']} for k in tid_to_text.keys()),
        'paragraphs': list({'id': k, 'text': pid_to_text[k]} for k in pid_to_text.keys()),
        'sentences': list({'id': k, 'text': sid_to_text[k]} for k in sid_to_text.keys()),
        'extractions': list({'id': k, 'body': eid_to_text[k]} for k in eid_to_text.keys()),
        'entities': list({'id': k, 'text': xid_to_text[k][0], 'tags': xid_to_text[k][1], 'tokens': xid_to_text[k][2]} for k in xid_to_text.keys())
    }
    
    triples = {
        'main': list(other_edges),
        'subjects': list(subject_edges),
        'modifiers': list(modifier_edges),
        'subject_modifiers': list(subject_modifier_edges),
        'relations': list(relation_edges)
    }
    return vertices, triples

# %%
print(extract('Any condition arising in the B.Tech. program and not covered in the regulations shall be referred to the UG committee.'))
print(extract('I create and play games and puzzles and play sports.'))
print(extract('I create games if I have time.'))
print(extract('If I have time I create games.'))
print(extract('I have time which is used for games.'))
print(extract('Any problem shall be referred to the UG committee which may refer it to the Senate.'))
print(nlp('There will not be any late registration in the summer term and a student shall not be allowed to add a course after registration.'))
print(get_sentence_structure('After graduating from Columbia University in 1983, he worked as a community organizer in Chicago'))
# Out:
# []
# [{'subject': 'I', 'relation': 'create', 'object': 'games', 'modifiers': [], 'subject_modifiers': [], 'condition': None}, {'subject': 'I', 'relation': 'create', 'object': 'puzzles', 'modifiers': [], 'subject_modifiers': [], 'condition': None}, {'subject': 'I', 'relation': 'play', 'object': 'games', 'modifiers': [], 'subject_modifiers': [], 'condition': None}, {'subject': 'I', 'relation': 'play', 'object': 'puzzles', 'modifiers': [], 'subject_modifiers': [], 'condition': None}, {'subject': 'I', 'relation': 'play', 'object': 'sports', 'modifiers': [], 'subject_modifiers': [], 'condition': None}]
# [{'subject': 'I', 'relation': 'create', 'object': 'games', 'modifiers': [], 'subject_modifiers': [], 'condition': 'I have time'}]
# [{'subject': 'I', 'relation': 'create', 'object': 'games', 'modifiers': [], 'subject_modifiers': [], 'condition': 'I have time'}]
# [{'subject': 'I', 'relation': 'have', 'object': 'time', 'modifiers': [{'m_rel': 'which is used for', 'm_obj': 'games'}], 'subject_modifiers': [], 'condition': None}]
# [{'subject': 'Any problem', 'relation': 'shall be referred to', 'object': 'the UG committee', 'modifiers': [{'m_rel': 'which may refer', 'm_obj': 'it'}, {'m_rel': 'to', 'm_obj': 'the Senate'}], 'subject_modifiers': [], 'condition': None}]
# There will not be any late registration in the summer term and a student shall not be allowed to add a course after registration.
# ('AAANNAN,NVCNNNAN', ['After', 'graduating', 'from', 'Columbia', 'University', 'in', '1983', ',', 'he', 'worked', 'as', 'a', 'community', 'organizer', 'in', 'Chicago'])

# %%
triples = None
vertices = None
documents = ['../data/files/UG-Regulations']

vertices, triples = create_kg(documents)
print('did, tid, pid, sid, eid, count, percentage')
# Out:
# keyword ('student senate', ['committee'], ['senate'])
# keyword ('main statutory body', [], ['main', 'statutory', 'body'])
# keyword ('academic matter', [], ['academic', 'matter'])
# keyword ('undergraduate committee', ['committee'], ['undergraduate', 'committee', 'ugc'])
# keyword ('standing committee', ['committee'], ['standing', 'committee'])
# keyword ('matter', [], ['matter'])
# keyword ('btech program', ['program'], ['undergraduate', 'program'])
# keyword ('condition', [], ['condition'])
# keyword ('regulation', [], ['regulation'])
# keyword ('it', [], [])
# keyword ('doaa doaa', ['person', 'faculty', 'doaa doaa'], ['doaa', 'doaa'])
# keyword ('main functionary', [], ['main', 'functionary'])
# keyword ('smooth functioning', [], ['smooth', 'functioning'])
# keyword ('academic program', ['program'], ['academic', 'program'])
# keyword ('policy', [], ['policy'])
# keyword ('decision', [], ['decision'])
# keyword ('pgc', [], ['pgc'])
# keyword ('doaa doaa ’s office', ['person', 'faculty', 'doaa doaa ’s office'], ['doaa', 'doaa', '’s', 'office'])
# keyword ('process', [], ['process'])
# keyword ('record', [], ['record'])
# keyword ('course', ['course'], ['course'])
# keyword ('academic calendar', [], ['academic', 'calendar'])
# keyword ('registration', ['registration'], ['registration'])
# keyword ('examination', [], ['examination'])
# keyword ('grade', ['grades'], ['grade'])
# keyword ('award', [], ['award'])
# keyword ('degree', [], ['degree'])
# keyword ('prize', [], ['prize'])
# keyword ('information', [], ['information'])
# keyword ('issue order', [], ['issue', 'order'])
# keyword ('request', [], ['request'])
# keyword ('student regarding academic matter', [], ['student', 'regarding', 'academic', 'matter'])
# keyword ('august 1', ['datetime'], ['august', '1'])
# keyword ('last week', ['datetime'], ['last', 'week'])
# keyword ('november', ['datetime'], ['november'])
# keyword ('january 2', ['datetime'], ['january', '2'])
# keyword ('april', ['datetime'], ['april'])
# keyword ('middle', [], ['middle'])
# keyword ('may', ['datetime'], ['may'])
# keyword ('july', ['datetime'], ['july'])
# keyword ('last 10 day', ['datetime'], ['last', '10', 'day'])
# keyword ('mid - semester', ['semester'], ['mid', '-', 'semester'])
# keyword ('endsem', ['evaluation'], ['end', 'semester', 'examination'])
# keyword ('presentation', [], ['presentation'])
# keyword ('demo', [], ['demo'])
# keyword ('summer semester', ['semester'], ['summer', 'term'])
# keyword ('duration', [], ['duration'])
# keyword ('regular semester', ['semester'], ['regular', 'semester'])
# keyword ('faster pace', [], ['faster', 'pace'])
# keyword ('year', ['datetime'], ['year'])
# keyword ('semester', ['semester'], ['semester'])
# keyword ('date', [], ['date'])
# keyword ('major academic activity', [], ['major', 'academic', 'activity'])
# keyword ('mid - semester recess', ['holiday'], ['mid', '-', 'semester', 'recess'])
# keyword ('doaa', ['person', 'faculty', 'doaa'], ['doaa'])
# keyword ('total number', ['number'], ['total', 'number'])
# keyword ('seat', [], ['seat'])
# keyword ('board', [], ['board'])
# keyword ('governor', [], ['governor'])
# keyword ('admission prospectus', ['admission'], ['admission', 'prospectus'])
# keyword ('change', [], ['change'])
# keyword ('merit list', [], ['merit', 'list'])
# keyword ('admission', ['admission'], ['admission'])
# keyword ('minimum eligibility criterion', [], ['minimum', 'eligibility', 'criterion'])
# keyword ('applying', [], ['applying'])
# keyword ('candidate', [], ['candidate'])
# keyword ('80 percent', ['number'], ['80', 'percent'])
# keyword ('more mark', [], ['more', 'mark'])
# keyword ('aggregate', [], ['aggregate'])
# keyword ('80 %', ['number'], ['80', '%'])
# keyword ('more', [], ['more'])
# keyword ('csam', ['department'], ['mathematic'])
# keyword ('class xii', [], ['class', 'xii'])
# keyword ('cbse', [], ['cbse'])
# keyword ('icse', [], ['icse'])
# keyword ('ib board', [], ['ib', 'board'])
# keyword ('equivalent', [], ['equivalent'])
# keyword ('eligible', [], ['eligible'])
# keyword ('iiitd', ['org'], ['iiit', 'delhi'])
# keyword ('relaxation', [], ['relaxation'])
# keyword ('category student', ['person', 'student'], ['category', 'student'])
# keyword ('prospectus', [], ['prospectus'])
# keyword ('additional requirement', [], ['additional', 'requirement'])
# keyword ('minimum eligibility', [], ['minimum', 'eligibility'])
# keyword ('specific program', ['program'], ['specific', 'program'])
# keyword ('candidate program', ['program'], ['candidate', 'program'])
# keyword ('other university', [], ['other', 'university'])
# keyword ('disciplinary ground', [], ['disciplinary', 'ground'])
# keyword ('those', [], [])
# keyword ('school', [], ['school'])
# keyword ('delhi government', [], ['delhi', 'government'])
# keyword ('15 %', ['number'], ['15', '%'])
# keyword ('outside delhi government candidate', [], ['outside', 'delhi', 'government', 'candidate'])
# keyword ('category wise reservation', [], ['category', 'wise', 'reservation'])
# keyword ('limit', [], ['limit'])
# keyword ('counseling', [], ['counseling'])
# keyword ('original document', [], ['original', 'document'])
# keyword ('verification', [], ['verification'])
# keyword ('admission form', ['admission'], ['admission', 'form'])
# keyword ('he', [], [])
# keyword ('she', [], [])
# keyword ('required fee', ['fee'], ['required', 'fee'])
# keyword ('admission formality', ['admission'], ['admission', 'formality'])
# keyword ('candidate unable', [], ['candidate', 'unable'])
# keyword ('proof', [], ['proof'])
# keyword ('fulfilling eligibility criterion', [], ['fulfilling', 'eligibility', 'criterion'])
# keyword ('provisional admission subject', ['admission'], ['provisional', 'admission', 'subject'])
# keyword ('fulfilling eligibility criterion presenting proof', [], ['fulfilling', 'eligibility', 'criterion', 'presenting', 'proof'])
# keyword ('following september 30th', ['datetime'], ['following', 'september', '30th'])
# keyword ('material information', [], ['material', 'information'])
# keyword ('incorrect', [], ['incorrect'])
# keyword ('fee', ['fee'], ['fee'])
# keyword ('the', [], [])
# keyword ('day', ['datetime'], ['day'])
# keyword ('right', [], ['right'])
# keyword ('reporting', [], ['reporting'])
# keyword ('depositing fee', ['fee'], ['depositing', 'fee'])
# keyword ('case', [], ['case'])
# keyword ('genuine', [], ['genuine'])
# keyword ('student', ['person', 'student'], ['student'])
# keyword ('later date', [], ['later', 'date'])
# keyword ('false information', [], ['false', 'information'])
# keyword ('relevant information', [], ['relevant', 'information'])
# keyword ('seeking admission', ['admission'], ['seeking', 'admission'])
# keyword ('these', [], [])
# keyword ('supernumerary', [], ['supernumerary'])
# keyword ('such seat', [], ['such', 'seat'])
# keyword ('non - degree student', ['person', 'student'], ['non', '-', 'degree', 'student'])
# keyword ('a', [], ['a'])
# keyword ('university', [], ['university'])
# keyword ('india', [], ['india'])
# keyword ('part', [], ['part'])
# keyword ('academic requirement', [], ['academic', 'requirement'])
# keyword ('such student', ['person', 'student'], ['such', 'student'])
# keyword ('academic', [], ['academic'])
# keyword ('disciplinary rule', [], ['disciplinary', 'rule'])
# keyword ('3 hour', ['datetime'], ['3', 'hour'])
# keyword ('lecture', [], ['lecture'])
# keyword ('week', ['datetime'], ['week'])
# keyword ('total', [], ['total'])
# keyword ('39 hour', ['datetime'], ['39', 'hour'])
# keyword ('lecture 13 week', ['datetime'], ['lecture', '13', 'week'])
# keyword ('addition', [], ['addition'])
# keyword ('one hour', ['datetime'], ['one', 'hour'])
# keyword ('interaction', [], ['interaction'])
# keyword ('form', [], ['form'])
# keyword ('structured tutorial', [], ['structured', 'tutorial'])
# keyword ('intensive short term course', ['course'], ['intensive', 'short', 'term', 'course'])
# keyword ('2 credit', ['number', 'credit'], ['2', 'credit'])
# keyword ('possible', [], ['possible'])
# keyword ('less', [], ['less'])
# keyword ('3 week', ['datetime'], ['3', 'week'])
# keyword ('likely', [], ['likely'])
# keyword ('short course', ['course'], ['short', 'course'])
# keyword ('specialized topic', [], ['specialized', 'topic'])
# keyword ('certain course such', ['course'], ['certain', 'course', 'such'])
# keyword ('self growth', ['course'], ['selfgrowth', 'sg'])
# keyword ('community work', ['course'], ['community', 'work', 'cw'])
# keyword ('varying number', ['number'], ['varying', 'number'])
# keyword ('credit', ['number', 'credit'], ['credit'])
# keyword ('case basis', [], ['case', 'basis'])
# keyword ('taking course', ['course'], ['taking', 'course'])
# keyword ('primary means', [], ['primary', 'means'])
# keyword ('there', [], ['there'])
# keyword ('other', [], ['other'])
# keyword ('provision', [], ['provision'])
# keyword ('earning credit', ['number', 'credit'], ['earning', 'credit'])
# keyword ('project', [], ['project'])
# keyword ('other institution', [], ['other', 'institution'])
# keyword ('transferring credit', ['number', 'credit'], ['transferring', 'credit'])
# keyword ('system', [], ['system'])
# keyword ('allowing student', ['person', 'student'], ['allowing', 'student'])
# keyword ('online course', ['course'], ['online', 'course'])
# keyword ('advantage', [], ['advantage'])
# keyword ('increasing amount', [], ['increasing', 'amount'])
# keyword ('such course', ['course'], ['such', 'course'])
# keyword ('available', [], ['available'])
# keyword ('reputed university', [], ['reputed', 'university'])
# keyword ('world', [], ['world'])
# keyword ('limit one course', ['number'], ['limit', 'one', 'course'])
# keyword ('oc', [], ['oc'])
# keyword ('4 credit', ['number', 'credit'], ['4', 'credit'])
# keyword ('beginning', [], ['beginning'])
# keyword ('course student', ['person', 'student'], ['course', 'student'])
# keyword ('necessary pre - requisite', [], ['necessary', 'pre', '-', 'requisite'])
# keyword ('registration process', ['registration'], ['registration', 'process'])
# keyword ('two part academic', ['number'], ['two', 'part', 'academic'])
# keyword ('administrative', [], ['administrative'])
# keyword ('both', [], [])
# keyword ('order', [], ['order'])
# keyword ('academic registration', ['registration'], ['academic', 'registration'])
# keyword ('specifying course student', ['person', 'student'], ['specifying', 'course', 'student'])
# keyword ('getting necessary approval', [], ['getting', 'necessary', 'approval'])
# keyword ('late registration', ['registration'], ['late', 'registration'])
# keyword ('payment', [], ['payment'])
# keyword ('late registration fee', ['registration'], ['late', 'registration', 'fee'])
# keyword ('delay', [], ['delay'])
# keyword ('due', [], ['due'])
# keyword ('academic activity', [], ['academic', 'activity'])
# keyword ('prior permission', [], ['prior', 'permission'])
# keyword ('number', ['number'], ['number'])
# keyword ('late arrival', [], ['late', 'arrival'])
# keyword ('leave', [], ['leave'])
# keyword ('absence', [], ['absence'])
# keyword ('late academic registration', ['registration'], ['late', 'academic', 'registration'])
# keyword ('case student', ['person', 'student'], ['case', 'student'])
# keyword ('pre - registration', ['registration'], ['pre', '-', 'registration'])
# keyword ('penalty', [], ['penalty'])
# keyword ('student preference', [], ['student', 'preference'])
# keyword ('period', [], ['period'])
# keyword ('adding', [], ['adding'])
# keyword ('dropping course', ['course'], ['dropping', 'course'])
# keyword ('last date', [], ['last', 'date'])
# keyword ('add', [], ['add'])
# keyword ('one elective course', ['number'], ['one', 'elective', 'course'])
# keyword ('midsem', ['evaluation'], ['mid', '-', 'semester', 'examination'])
# keyword ('backlog', [], ['backlog'])
# keyword ('course(s', ['course'], ['course(s'])
# keyword ('previous semester(s', [], ['previous', 'semester(s'])
# keyword ('manner student', ['person', 'student'], ['manner', 'student'])
# keyword ('many backlog course', ['course'], ['many', 'backlog', 'course'])
# keyword ('responsible', [], ['responsible'])
# keyword ('proper registration', ['registration'], ['proper', 'registration'])
# keyword ('satisfied', [], ['satisfied'])
# keyword ('timetable clash', [], ['timetable', 'clash'])
# keyword ('student ’s registration', ['registration'], ['student', '’s', 'registration'])
# keyword ('disciplinary action', [], ['disciplinary', 'action'])
# keyword ('permissible limit', [], ['permissible', 'limit'])
# keyword ('cancellation', [], ['cancellation'])
# keyword ('optional', [], ['optional'])
# keyword ('6 credit', ['number', 'credit'], ['6', 'credit'])
# keyword ('cw credit', ['number', 'credit'], ['cw', 'credit'])
# keyword ('2nd year', ['datetime'], ['2nd', 'year'])
# keyword ('cw credits btech program', ['number', 'credit'], ['cw', 'credits', 'btech', 'program'])
# keyword ('ip', ['course'], ['ip'])
# keyword ('ur', [], ['ur'])
# keyword ('btp', ['course'], ['btp'])
# keyword ('exception', [], ['exception'])
# keyword ('graduating batch', ['graduation'], ['graduating', 'batch'])
# keyword ('8 credit', ['number', 'credit'], ['8', 'credit'])
# keyword ('general', [], ['general'])
# keyword ('program', ['program'], ['program'])
# keyword ('more credit', ['number', 'credit'], ['more', 'credit'])
# keyword ('normal load', [], ['normal', 'load'])
# keyword ('overload', [], ['overload'])
# keyword ('16 credit', ['number', 'credit'], ['16', 'credit'])
# keyword ('underload', [], ['underload'])
# keyword ('permission', [], ['permission'])
# keyword ('doaa underload', ['person', 'faculty', 'doaa underload'], ['doaa', 'underload'])
# keyword ('maximum', [], ['maximum'])
# keyword ('taking semester leave', ['semester'], ['taking', 'semester', 'leave'])
# keyword ('prior approval', [], ['prior', 'approval'])
# keyword ('one semester', ['number'], ['one', 'semester'])
# keyword ('student wanting', [], ['student', 'wanting'])
# keyword ('internship industrial', [], ['internship', 'industrial'])
# keyword ('research', [], ['research'])
# keyword ('taking semester leave degree program', ['program'], ['taking', 'semester', 'leave', 'degree', 'program'])
# keyword ('such internship', [], ['such', 'internship'])
# keyword ('only ip', ['course'], ['only', 'ip'])
# keyword ('oc course', ['course'], ['oc', 'course'])
# keyword ('low', [], ['low'])
# keyword ('ece', ['department'], ['ece'])
# keyword ('csss student', ['person', 'student'], ['csss', 'student'])
# keyword ('3rd', ['number'], ['3rd'])
# keyword ('4th year', ['datetime'], ['4th', 'year'])
# keyword ('cse', ['department'], ['cse'])
# keyword ('csd', ['department'], ['csd'])
# keyword ('csb student', ['person', 'student'], ['csb', 'student'])
# keyword ('8th semester', ['number'], ['8th', 'semester'])
# keyword ('continuous evaluation', ['evaluation'], ['continuous', 'evaluation'])
# keyword ('various instrument', [], ['various', 'instrument'])
# keyword ('test', ['evaluation'], ['test'])
# keyword ('exam', ['evaluation'], ['exam'])
# keyword ('assignment', ['evaluation'], ['assignment'])
# keyword ('faculty', ['person', 'faculty'], ['instructor'])
# keyword ('learning', [], ['learning'])
# keyword ('valid reason such', [], ['valid', 'reason', 'such'])
# keyword ('illness', [], ['illness'])
# keyword ('one', ['number'], ['one'])
# keyword ('academic office', [], ['academic', 'office'])
# keyword ('two day', ['datetime'], ['two', 'day'])
# keyword ('scheduled examination', [], ['scheduled', 'examination'])
# keyword ('proper documentary evidence', [], ['proper', 'documentary', 'evidence'])
# keyword ('justifying request', [], ['justifying', 'request'])
# keyword ('medical reason', [], ['medical', 'reason'])
# keyword ('two medical application including mid - semester', ['number'], ['two', 'medical', 'application', 'including', 'mid', '-', 'semester'])
# keyword ('end semester', ['semester'], ['end', 'semester'])
# keyword ('entire duration', [], ['entire', 'duration'])
# keyword ('medical certificate', [], ['medical', 'certificate'])
# keyword ('i incomplete grade', ['grades'], ['i', 'incomplete', 'grade'])
# keyword ('requirement', [], ['requirement'])
# keyword ('time', [], ['time'])
# keyword ('submission', [], ['submission'])
# keyword ('incomplete status', [], ['incomplete', 'status'])
# keyword ('erp', ['link'], ['evaluation', 'resource', 'planning', 'erp', 'system'])
# keyword ('course including project', ['course'], ['course', 'including', 'project'])
# keyword ('regular grade', ['grades'], ['regular', 'grade'])
# keyword ('one month', ['datetime'], ['one', 'month'])
# keyword ('end', [], ['end'])
# keyword ('current term', ['semester'], ['current', 'term'])
# keyword ('moderation date', [], ['moderation', 'date'])
# keyword ('all', [], [])
# keyword ('grades', ['grades'], ['grades'])
# keyword ('f grade', ['grades'], ['f', 'grade'])
# keyword ('grade conversion deadline', ['grades'], ['grade', 'conversion', 'deadline'])
# keyword ('certain course', ['course'], ['certain', 'course'])
# keyword ('such', [], ['such'])
# keyword ('online course oc', ['course'], ['online', 'course', 'oc'])
# keyword ('s', [], ['s'])
# keyword ('x grade', ['grades'], ['x', 'grade'])
# keyword ('f', [], ['f'])
# keyword ('compulsory course', ['course'], ['compulsory', 'course'])
# keyword ('same course', ['course'], ['same', 'course'])
# keyword ('summer', [], ['summer'])
# keyword ('one compulsory core course', ['number'], ['one', 'compulsory', 'core', 'course'])
# keyword ('getting f', [], ['getting', 'f'])
# keyword ('elective course', ['course'], ['elective', 'course'])
# keyword ('respective discipline', [], ['respective', 'discipline'])
# keyword ('new grade', ['grades'], ['new', 'grade'])
# keyword ('computation', [], ['computation'])
# keyword ('cgpa', ['grades', 'gpa'], ['cgpa'])
# keyword ('pass grade', ['grades'], ['pass', 'grade'])
# keyword ('respective course', ['course'], ['respective', 'course'])
# keyword ('sgpa', ['grades', 'gpa'], ['sgpa'])
# keyword ('calculation', [], ['calculation'])
# keyword ('ordinance', [], ['ordinance'])
# keyword ('letter grade', ['grades'], ['letter', 'grade'])
# keyword ('charge', [], ['charge'])
# keyword ('chairman', ['person', 'faculty', 'chairman'], ['chairman'])
# keyword ('such request', [], ['such', 'request'])
# keyword ('four week', ['datetime'], ['four', 'week'])
# keyword ('start', [], ['start'])
# keyword ('next semester', ['semester'], ['next', 'semester'])
# keyword ('relevant record', [], ['relevant', 'record'])
# keyword ('justification', [], ['justification'])
# keyword ('student ’ performance', [], ['student', '’', 'performance'])
# keyword ('refresher module', [], ['refresher', 'module'])
# keyword ('d grade', ['grades'], ['d', 'grade'])
# keyword ('letter grade improvement', ['grades'], ['letter', 'grade', 'improvement'])
# keyword ('improvement', [], ['improvement'])
# keyword ('d', [], ['d'])
# keyword ('c-', [], ['c-'])
# keyword ('decision regarding', [], ['decision', 'regarding'])
# keyword ('module', [], ['module'])
# keyword ('vacation', ['holiday'], ['vacation'])
# keyword ('grade enhancement', ['grades'], ['grade', 'enhancement'])
# keyword ('grade change', ['grades'], ['grade', 'change'])
# keyword ('grade improvement', ['grades'], ['grade', 'improvement'])
# keyword ('attempt', [], ['attempt'])
# keyword ('respective semester ’ transcript', ['semester'], ['respective', 'semester', '’', 'transcript'])
# keyword ('repeat course', ['course'], ['repeat', 'course'])
# keyword ('late drop', [], ['late', 'drop'])
# keyword ('sgpa u1.w1', ['number'], ['sgpa', 'u1.w1'])
# keyword ('u2.w2 un.wn', ['number'], ['u2.w2', 'un.wn'])
# keyword ('u1 + u2 un', ['number'], ['u1', '+', 'u2', 'un'])
# keyword ('ui', [], ['ui'])
# keyword ('wi', [], ['wi'])
# keyword ('point', [], ['point'])
# keyword ('doing computation', [], ['doing', 'computation'])
# keyword ('thesis credit', ['number', 'credit'], ['thesis', 'credit'])
# keyword ('grade s', ['grades'], ['grade', 's'])
# keyword ('x', [], ['x'])
# keyword ('overall performance', [], ['overall', 'performance'])
# keyword ('cumulative grade point average cgpa', ['grades'], ['cumulative', 'grade', 'point', 'average', 'cgpa'])
# keyword ('same manner', [], ['same', 'manner'])
# keyword ('grade report', ['grades'], ['grade', 'report'])
# keyword ('other due', [], ['other', 'due'])
# keyword ('disciplinary case', [], ['disciplinary', 'case'])
# keyword ('her', [], [])
# keyword ('other formality', [], ['other', 'formality'])
# keyword ('other pertinent reason', [], ['other', 'pertinent', 'reason'])
# keyword ('performance', [], ['performance'])
# keyword ('quantum', [], ['quantum'])
# keyword ('work', [], ['work'])
# keyword ('content', [], ['content'])
# keyword ('similar course', ['course'], ['similar', 'course'])
# keyword ('institution', [], ['institution'])
# keyword ('arrangement', [], ['arrangement'])
# keyword ('mou', [], ['mou'])
# keyword ('student exchange program', ['program'], ['student', 'exchange', 'program'])
# keyword ('transfer', [], ['transfer'])
# keyword ('n extra credit', ['number', 'credit'], ['n', 'extra', 'credit'])
# keyword ('worst grade', ['grades'], ['worst', 'grade'])
# keyword ('n credit', ['number', 'credit'], ['n', 'credit'])
# keyword ('maximum limit', [], ['maximum', 'limit'])
# keyword ('most 8 credit', ['number', 'credit'], ['most', '8', 'credit'])
# keyword ('cgpa computation', ['grades'], ['cgpa', 'computation'])
# keyword ('impact', [], ['impact'])
# keyword ('two batch', ['number'], ['two', 'batch'])
# keyword ('option', [], ['option'])
# keyword ('method below method', [], ['method', 'below', 'method'])
# keyword ('extra credit', ['number', 'credit'], ['extra', 'credit'])
# keyword ('n credit more', ['number', 'credit'], ['n', 'credit', 'more'])
# keyword ('116', ['number'], ['116'])
# keyword ('cgpa computation following', ['grades'], ['cgpa', 'computation', 'following'])
# keyword ('course totaling m credit', ['number', 'credit'], ['course', 'totaling', 'm', 'credit'])
# keyword ('m= min{8', ['number'], ['m=', 'min{8'])
# keyword ('n', [], ['n'])
# keyword ('oc ’s', [], ['oc', '’s'])
# keyword ('baseline 116 credit', ['number', 'credit'], ['baseline', '116', 'credit'])
# keyword ('example', [], ['example'])
# keyword ('120 credit including oc', ['number', 'credit'], ['120', 'credit', 'including', 'oc'])
# keyword ('best grade', ['grades'], ['best', 'grade'])
# keyword ('112 credit', ['number', 'credit'], ['112', 'credit'])
# keyword ('honor student', ['person', 'student'], ['honor', 'student'])
# keyword ('similar', [], ['similar'])
# keyword ('non - honor student', ['person', 'student'], ['non', '-', 'honor', 'student'])
# keyword ('164 credit excluding sg', ['number', 'credit'], ['164', 'credit', 'excluding', 'sg'])
# keyword ('cw credit including oc', ['number', 'credit'], ['cw', 'credit', 'including', 'oc'])
# keyword ('152 credit', ['number', 'credit'], ['152', 'credit'])
# keyword ('same', [], ['same'])
# keyword ('first 5 semester', ['number'], ['first', '5', 'semester'])
# keyword ('btech student', ['person', 'student'], ['btech', 'student'])
# keyword ('minimum', [], ['minimum'])
# keyword ('8 semester', ['number'], ['8', 'semester'])
# keyword ('most two extra course', ['number'], ['most', 'two', 'extra', 'course'])
# keyword ('completion', [], ['completion'])
# keyword ('156 credit', ['number', 'credit'], ['156', 'credit'])
# keyword ('graduation', ['graduation'], ['graduation'])
# keyword ('one extra semester', ['number'], ['one', 'extra', 'semester'])
# keyword ('extra semester', ['semester'], ['extra', 'semester'])
# keyword ('academic performance', [], ['academic', 'performance'])
# keyword ('first year', ['datetime'], ['first', 'year'])
# keyword ('warning', [], ['warning'])
# keyword ('student program', ['program'], ['student', 'program'])
# keyword ('detail', [], ['detail'])
# keyword ('department wise technical', [], ['department', 'wise', 'technical'])
# keyword ('non - technical course', ['course'], ['non', '-', 'technical', 'course'])
# keyword ('program wise regulation', ['program'], ['program', 'wise', 'regulation'])
# keyword ('3', ['number'], ['3'])
# keyword ('less technical course', ['course'], ['less', 'technical', 'course'])
# keyword ('entire first year', ['datetime'], ['entire', 'first', 'year'])
# keyword ('semester leave', ['semester'], ['semester', 'leave'])
# keyword ('any', [], [])
# keyword ('two semester', ['number'], ['two', 'semester'])
# keyword ('either', [], ['either'])
# keyword ('first semester', ['semester'], ['first', 'semester'])
# keyword ('next academic year', ['datetime'], ['next', 'academic', 'year'])
# keyword ('third semester', ['semester'], ['third', 'semester'])
# keyword ('semester 2', ['number'], ['semester', '2'])
# keyword ('rule 2', ['number'], ['rule', '2'])
# keyword ('student repeating first year', ['datetime'], ['student', 'repeating', 'first', 'year'])
# keyword ('1 technical course', ['number'], ['1', 'technical', 'course'])
# keyword ('repeat year', ['datetime'], ['repeat', 'year'])
# keyword ('student repeating first year program', ['datetime'], ['student', 'repeating', 'first', 'year', 'program'])
# keyword ('non- technical course student repeating first year', ['datetime'], ['non-', 'technical', 'course', 'student', 'repeating', 'first', 'year'])
# keyword ('student repeating first year previous attempt', ['datetime'], ['student', 'repeating', 'first', 'year', 'previous', 'attempt'])
# keyword ('regular rule', [], ['regular', 'rule'])
# keyword ('4.5', ['number'], ['4.5'])
# keyword ('post', [], ['post'])
# keyword ('hostel', ['location', 'building'], ['institute', 'body', 'including', 'hostel', 'management'])
# keyword ('student ’ activity', [], ['student', '’', 'activity'])
# keyword ('student council', ['committee'], ['student', 'council'])
# keyword ('undertaking', [], ['undertaking'])
# keyword ('academic warning', [], ['academic', 'warning'])
# keyword ('low sgpa', ['grades'], ['low', 'sgpa'])
# keyword ('4.0', ['number'], ['4.0'])
# keyword ('two consecutive semester', ['number'], ['two', 'consecutive', 'semester'])
# keyword ('two', ['number'], ['two'])
# keyword ('more f', [], ['more', 'f'])
# keyword ('each', [], [])
# keyword ('student attendance', [], ['student', 'attendance'])
# keyword ('threshold', [], ['threshold'])
# keyword ('valid reason', [], ['valid', 'reason'])
# keyword ('including', [], ['including'])
# keyword ('limited', [], ['limited'])
# keyword ('ill health', [], ['ill', 'health'])
# keyword ('internship', [], ['internship'])
# keyword ('entrepreneurship', [], ['entrepreneurship'])
# keyword ('family requirement', [], ['family', 'requirement'])
# keyword ('critical reason such', [], ['critical', 'reason', 'such'])
# keyword ('such case', [], ['such', 'case'])
# keyword ('fee refund', ['fee'], ['fee', 'refund'])
# keyword ('admissible', [], ['admissible'])
# keyword ('circumstance', [], ['circumstance'])
# keyword ('four semester leave', ['number'], ['four', 'semester', 'leave'])
# keyword ('automatic termination', [], ['automatic', 'termination'])
# keyword ('entire program', ['program'], ['entire', 'program'])
# keyword ('this', [], [])
# keyword ('present', [], ['present'])
# keyword ('student degree program', ['program'], ['student', 'degree', 'program'])
# keyword ('event', [], ['event'])
# keyword ('dean', ['person', 'faculty', 'dean'], ['dean'])
# keyword ('student affairs', [], ['student', 'affairs'])
# keyword ('participation', [], ['participation'])
# keyword ('such appeal', [], ['such', 'appeal'])
# keyword ('two week', ['datetime'], ['two', 'week'])
# keyword ('final', [], ['final'])
# keyword ('one program', ['number'], ['one', 'program'])
# keyword ('only time branch change', [], ['only', 'time', 'branch', 'change'])
# keyword ('explicit request', [], ['explicit', 'request'])
# keyword ('program transfer', ['program'], ['program', 'transfer'])
# keyword ('announcement', [], ['announcement'])
# keyword ('result', [], ['result'])
# keyword ('rule', [], ['rule'])
# keyword ('eligibility', [], ['eligibility'])
# keyword ('particular branch', [], ['particular', 'branch'])
# keyword ('branch', [], ['branch'])
# keyword ('aicte', [], ['aicte'])
# keyword ('noc', [], ['noc'])
# keyword ('to', [], ['to'])
# keyword ('csss', ['department'], ['csss', 'csss', 'program'])
# keyword ('cdb', ['department'], ['csb', 'csb', 'program'])
# keyword ('b', [], ['b'])
# keyword ('better grade', ['grades'], ['better', 'grade'])
# keyword ('introduction', [], ['introduction'])
# keyword ('programming ip', ['course'], ['programming', 'ip'])
# keyword ('electronic', [], ['electronic'])
# keyword ('digital circuit', [], ['digital', 'circuit'])
# keyword ('student eligible', [], ['student', 'eligible'])
# keyword ('priority list', [], ['priority', 'list'])
# keyword ('strength', [], ['strength'])
# keyword ('following limit', [], ['following', 'limit'])
# keyword ('base strength', [], ['base', 'strength'])
# keyword ('batch', [], ['batch'])
# keyword ('dec 15', ['datetime'], ['dec', '15'])
# keyword ('sem 1', ['number'], ['sem', '1'])
# keyword ('counting', [], ['counting'])
# keyword ('110 student', ['person', 'student'], ['110', 'student'])
# keyword ('8 repeater', ['number'], ['8', 'repeater'])
# keyword ('6', ['number'], ['6'])
# keyword ('110 6=104', ['number'], ['110', '6=104'])
# keyword ('repeater', [], ['repeater'])
# keyword ('branch transfer', [], ['branch', 'transfer'])
# keyword ('tie', [], ['tie'])
# keyword ('tie breaking rule', [], ['tie', 'breaking', 'rule'])
# keyword ('deciding transfer', [], ['deciding', 'transfer'])
# keyword ('one branch', ['number'], ['one', 'branch'])
# keyword ('another', [], [])
# keyword ('higher grade', ['grades'], ['higher', 'grade'])
# keyword ('programming', [], ['programming'])
# keyword ('system management', [], ['system', 'management'])
# keyword ('communication skill', [], ['communication', 'skill'])
# keyword ('tie breaking rule ii jee rank', [], ['tie', 'breaking', 'rule', 'ii', 'jee', 'rank'])
# keyword ('dual degree', [], ['dual', 'degree'])
# keyword ('migration', [], ['migration'])
# keyword ('dual degree 7th semester', ['number'], ['dual', 'degree', '7th', 'semester'])
# keyword ('placement service', [], ['placement', 'service'])
# keyword ('eligibility criterion', [], ['eligibility', 'criterion'])
# keyword ('maximum duration', [], ['maximum', 'duration'])
# keyword ('six year 12 semester including semester', ['datetime'], ['six', 'year', '12', 'semester', 'including', 'semester'])
# keyword ('eight semester', ['number'], ['eight', 'semester'])
# keyword ('program excluding semester', ['program'], ['program', 'excluding', 'semester'])
# keyword ('disciplinary proceeding', [], ['disciplinary', 'proceeding'])
# keyword ('him', [], [])
# keyword ('honor', [], ['honor'])
# keyword ('minor', [], ['minor'])
# keyword ('area', [], ['area'])
# keyword ('graduation requirement', ['graduation'], ['graduation', 'requirement'])
# keyword ('governor bog', [], ['governor', 'bog'])
# keyword ('convocation', [], ['convocation'])
# keyword ('satisfactory report', [], ['satisfactory', 'report'])
# keyword ('academic affair', [], ['academic', 'affair'])
# keyword ('pending actual award', [], ['pending', 'actual', 'award'])
# keyword ('regular convocation', [], ['regular', 'convocation'])
# keyword ('registrar', [], ['registrar'])
# keyword ('provisional certificate', [], ['provisional', 'certificate'])
# keyword ('may 21', ['datetime'], ['may', '21'])
# keyword ('winter semester example 8th semester', ['number'], ['winter', 'semester', 'example', '8th', 'semester'])
# keyword ('aug 21', ['datetime'], ['aug', '21'])
# keyword ('summer term dec 21', ['datetime'], ['summer', 'term', 'dec', '21'])
# keyword ('monsoon semester', ['semester'], ['monsoon', 'semester'])
# keyword ('exceptional circumstance', [], ['exceptional', 'circumstance'])
# keyword ('gross violation', [], ['gross', 'violation'])
# keyword ('use', [], ['use'])
# keyword ('dishonest mean', [], ['dishonest', 'mean'])
# keyword ('later stage', [], ['later', 'stage'])
# keyword ('an', [], [])
# keyword ('degree requirement', [], ['degree', 'requirement'])
# keyword ('december', ['datetime'], ['december'])
# keyword ('deserving student', ['person', 'student'], ['deserving', 'student'])
# keyword ('student award', [], ['student', 'award'])
# keyword ('prize selection criterion', [], ['prize', 'selection', 'criterion'])
# keyword ('award regulation', [], ['award', 'regulation'])
# keyword ('recognition', [], ['recognition'])
# keyword ('academic misconduct', [], ['academic', 'misconduct'])
# keyword ('action', [], ['action'])
# keyword ('act', [], ['act'])
# keyword ('indiscipline', [], ['indiscipline'])
# keyword ('academic dishonesty', [], ['academic', 'dishonesty'])
# keyword ('disciplinary action committee', ['committee'], ['disciplinary', 'action', 'committee', 'dac'])
# keyword ('director', [], ['director'])
# keyword ('all that', [], [])
# keyword ('above regulation', [], ['above', 'regulation'])
# ERROR: should
# ERROR: expulsion
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-2c56a8ee04c2> in <module>
#       3 documents = ['../data/files/UG-Regulations']
#       4
# ----> 5 vertices, triples = create_kg(documents)
#       6 print('did, tid, pid, sid, eid, count, percentage')
#
# <ipython-input-2-690c9174dc8f> in create_kg(documents)
#     131
#     132     # canonicalise the obtained extractions
# --> 133     canonicalise(eid_to_text)
#     134
#     135     # for each extraction create entities and relations
#
# ~/btp/iiitd_policy_chatbot/notebooks/helper.py in canonicalise(extractions)
#     565
#     566     # word sense disambiguation using wordnet
# --> 567     extractions = word_sense_disambiguation(extractions)
#     568     return extractions
#     569
#
# ~/btp/iiitd_policy_chatbot/notebooks/helper.py in word_sense_disambiguation(extractions)
#     310     words = set([])
#     311     for ext in extractions:
# --> 312         words.add(extractions[ext]['subject'])
#     313         words.add(extractions[ext]['object'])
#     314         for m in extractions[ext]['modifiers'] + extractions[ext]['subject_modifiers']:
#
# TypeError: unhashable type: 'list'

# %%
write_json({'vertices': vertices, 'edges': triples}, '../neo4j/graph.json')

# %% [raw]
# 1 101 361 725 207 588 done
# 1 87 300 665 202 582 done remove paras with < 5 words
# 1 87 284 648 202 582 done remove paras with < 6 words
# 1 86 264 628 199 579 done remove paras with < 7 words
# 2 91 307 697 241 671 done with 2 docs (+69 sentences, +42 extractions)
# 3 92 318 721 256 723 done with 3 docs (+24 sentences, +15 extractions)
# 3 92 318 721 256 717 done word sense disambiguation (-6 entities)

# %%
print(nlp('procedure').similarity(nlp('process')))
# Out:
# 0.657118382755142
